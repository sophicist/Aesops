# %% [markdown]
# # <font color = 'Teal'>Economic Indicators Analysis</font>

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from plotnine import *

# %%
df = pd.read_csv('global_development.csv')
#os.listdir()

# rename some columns
df = df.rename(columns = {'Data.Health.Life Expectancy at Birth, Female':"LifeExp_Female",
                          "Data.Health.Life Expectancy at Birth, Male":"LifeExp_Male"})
df.head()
# Out:
#   Country  Year  Data.Health.Birth Rate  Data.Health.Death Rate  \
# 0  Canada  1980                    15.4                     7.0
# 1  Canada  1981                    15.4                     7.1
# 2  Canada  1982                    15.3                     7.0
# 3  Canada  1983                    15.1                     7.1
# 4  Canada  1984                    15.0                     7.0
#
#    Data.Health.Fertility Rate  LifeExp_Female  LifeExp_Male  \
# 0                       1.754           78.59         71.32
# 1                       1.740           78.73         71.60
# 2                       1.700           79.11         72.02
# 3                       1.690           79.23         72.30
# 4                       1.680           79.55         72.69
#
#    Data.Health.Life Expectancy at Birth, Total  Data.Health.Population Growth  \
# 0                                    74.866341                       0.997669
# ...

# %%
# African Countries
east_africa = ['Uganda','Tanzania','Kenya','Rwanda']
df_east = df[df.Country.isin(east_africa)]


# ensure that the year is datetime
#df_east.Year  = pd.DatetimeIndex(df_east.Year)
df_east.head()
# Out:
#       Country  Year  Data.Health.Birth Rate  Data.Health.Death Rate  \
# 952  Tanzania  1980                  46.995                  15.596
# 953  Tanzania  1981                  46.739                  15.425
# 954  Tanzania  1982                  46.469                  15.279
# 955  Tanzania  1983                  46.199                  15.149
# 956  Tanzania  1984                  45.939                  15.029
#
#      Data.Health.Fertility Rate  LifeExp_Female  LifeExp_Male  \
# 952                       6.685          51.987        48.647
# 953                       6.653          52.191        48.876
# 954                       6.618          52.359        49.065
# 955                       6.580          52.508        49.227
# 956                       6.542          52.645        49.368
#
#      Data.Health.Life Expectancy at Birth, Total  \
# 952                                    50.276268
# 953                                    50.493073
# ...

# %%
data = pd.melt(df_east,id_vars = ["Country","Year"])
needed = ["LifeExp_Female","LifeExp_Male"]
needed = data[data.variable.isin(needed)]
(ggplot(needed,aes(x = 'Year',y = 'value',color = "Country"))+geom_line()+facet_grid('variable~')
)
# Out:
# <ggplot: (83075260392)>

# %% [markdown]
# ## The graph shows for example that rwanda had very low life expectancy especially between 1990 - 2000 during the genocide but that has improved and overtaken al the other countries
